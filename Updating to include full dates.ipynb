# %%
import pandas as pd

# %%
shelter = pd.read_csv(r'C:\Users\ardit\Desktop\python_course\Final Project\animalShelter.csv')
pd.set_option('display.max_columns', None)
shelter.head()
# Out:
#       id intakereason   animalname                breedname  \
# 0  15801       Moving       Jadzia      Domestic Short Hair
# 1  15932       Moving        Gonzo  German Shepherd Dog/Mix
# 2  28859    Abandoned       Maggie  Shep Mix/Siberian Husky
# 3  28859    Abandoned       Maggie  Shep Mix/Siberian Husky
# 4  30812    Abandoned  Pretty Girl      Domestic Short Hair
#
#              basecolour speciesname           animalage sexname movementtype  \
# 0         Tortoiseshell         Cat  11 years 8 months.  Female     Adoption
# 1                   Tan         Dog  10 years 9 months.    Male     Adoption
# 2               Various         Dog    8 years 1 month.  Female     Adoption
# 3               Various         Dog    8 years 1 month.  Female    Reclaimed
# 4  Dilute tortoiseshell         Cat  10 years 6 months.  Female       Foster
#
#    intakeDate movementDate CatAgeGroup DogAgeGroup  movementMonth  \
# 0  11/28/2009   05/13/2017      Senior      Senior              5
# ...

# %%
shelter.drop(['animalname', 'basecolour', 'animalage', 'intakeMonthR'], axis=1, inplace=True)

# %%
shelter.head()
# Out:
#       id intakereason                breedname speciesname sexname  \
# 0  15801       Moving      Domestic Short Hair         Cat  Female
# 1  15932       Moving  German Shepherd Dog/Mix         Dog    Male
# 2  28859    Abandoned  Shep Mix/Siberian Husky         Dog  Female
# 3  28859    Abandoned  Shep Mix/Siberian Husky         Dog  Female
# 4  30812    Abandoned      Domestic Short Hair         Cat  Female
#
#   movementtype  intakeDate movementDate CatAgeGroup DogAgeGroup  \
# 0     Adoption  11/28/2009   05/13/2017      Senior      Senior
# 1     Adoption  12/08/2009   04/24/2017      Mature      Senior
# 2     Adoption  08/10/2012   04/15/2017      Mature      Mature
# 3    Reclaimed  08/10/2012   02/29/2020      Mature      Mature
# 4       Foster  01/11/2013   04/18/2017      Mature      Senior
#
#    movementMonth  movementDay  movementYear  intakeMonth  intakeDay  \
# 0              5           13          2017           11         28
# ...

# %%
shelter1 = shelter[(shelter.CatAgeGroup != "Unknown") & (shelter.DogAgeGroup != "Unknown") & (shelter.sexname != "Unknown")]
shelter1.head()
# Out:
#       id intakereason                breedname speciesname sexname  \
# 0  15801       Moving      Domestic Short Hair         Cat  Female
# 1  15932       Moving  German Shepherd Dog/Mix         Dog    Male
# 2  28859    Abandoned  Shep Mix/Siberian Husky         Dog  Female
# 3  28859    Abandoned  Shep Mix/Siberian Husky         Dog  Female
# 4  30812    Abandoned      Domestic Short Hair         Cat  Female
#
#   movementtype  intakeDate movementDate CatAgeGroup DogAgeGroup  \
# 0     Adoption  11/28/2009   05/13/2017      Senior      Senior
# 1     Adoption  12/08/2009   04/24/2017      Mature      Senior
# 2     Adoption  08/10/2012   04/15/2017      Mature      Mature
# 3    Reclaimed  08/10/2012   02/29/2020      Mature      Mature
# 4       Foster  01/11/2013   04/18/2017      Mature      Senior
#
#    movementMonth  movementDay  movementYear  intakeMonth  intakeDay  \
# 0              5           13          2017           11         28
# ...

# %%
dictionary = { 'intakereason':
{ "Owner Died": "Owner Deceased" }}
shelter1.replace(dictionary, inplace=True)

# %%
shelter1.to_csv(r'C:\Users\ardit\Desktop\python_course\Final Project\shelterDates.csv', index = False)
