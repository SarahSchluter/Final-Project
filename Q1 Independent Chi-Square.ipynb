# %% [markdown]
# # Import packages

# %%
import pandas as pd
from scipy import stats

# %% [markdown]
# # Evaluation Question #1:
# # What time of year are cats and dogs more likely to get adopted?

# %% [markdown]
# # Read in data

# %%
shelter = pd.read_csv(r'C:\Users\ardit\Desktop\Final-Project\shelter.csv')
pd.set_option('display.max_columns', None)
shelter.head()
# Out:
#       id intakereason                breedname speciesname sexname  \
# 0  15801       Moving      Domestic Short Hair         Cat  Female
# 1  15932       Moving  German Shepherd Dog/Mix         Dog    Male
# 2  28859    Abandoned  Shep Mix/Siberian Husky         Dog  Female
# 3  28859    Abandoned  Shep Mix/Siberian Husky         Dog  Female
# 4  30812    Abandoned      Domestic Short Hair         Cat  Female
#
#   movementtype  intakeDate movementDate CatAgeGroup DogAgeGroup  \
# 0     Adoption  11/28/2009   05/13/2017      Senior      Senior
# 1     Adoption  12/08/2009   04/24/2017      Mature      Senior
# 2     Adoption  08/10/2012   04/15/2017      Mature      Mature
# 3    Reclaimed  08/10/2012   02/29/2020      Mature      Mature
# 4       Foster  01/11/2013   04/18/2017      Mature      Senior
#
#    movementMonth  movementDay  movementYear  intakeMonth  intakeDay  \
# 0              5           13          2017           11         28
# 1              4           24          2017           12          8
# 2              4           15          2017            8         10
# 3              2           29          2020            8         10
# 4              4           18          2017            1         11
#
#    intakeYear
# 0        2009
# 1        2009
# 2        2012
# 3        2012
# 4        2013

# %% [markdown]
# # Recode adoptions to 1 and all other movement types to 0

# %%
dictionaryMovement = { 'movementtype': 
{ "Adoption": 1,
  "Escaped": 0,
  "Foster": 0,
  "Reclaimed": 0,
  "Released To Wild": 0,
  "Stolen": 0,
  "Transfer": 0 }}
shelter.replace(dictionaryMovement, inplace=True)

# %%
shelter.head()
# Out:
#       id intakereason                breedname speciesname sexname  \
# 0  15801       Moving      Domestic Short Hair         Cat  Female
# 1  15932       Moving  German Shepherd Dog/Mix         Dog    Male
# 2  28859    Abandoned  Shep Mix/Siberian Husky         Dog  Female
# 3  28859    Abandoned  Shep Mix/Siberian Husky         Dog  Female
# 4  30812    Abandoned      Domestic Short Hair         Cat  Female
#
#    movementtype  intakeDate movementDate CatAgeGroup DogAgeGroup  \
# 0             1  11/28/2009   05/13/2017      Senior      Senior
# 1             1  12/08/2009   04/24/2017      Mature      Senior
# 2             1  08/10/2012   04/15/2017      Mature      Mature
# 3             0  08/10/2012   02/29/2020      Mature      Mature
# 4             0  01/11/2013   04/18/2017      Mature      Senior
#
#    movementMonth  movementDay  movementYear  intakeMonth  intakeDay  \
# 0              5           13          2017           11         28
# 1              4           24          2017           12          8
# 2              4           15          2017            8         10
# 3              2           29          2020            8         10
# 4              4           18          2017            1         11
#
#    intakeYear
# 0        2009
# 1        2009
# 2        2012
# 3        2012
# 4        2013

# %%
### Remove Unknown variables in age groups for better filtering
# shelter1 = shelter[(shelter.CatAgeGroup != "Unknown") & (shelter.DogAgeGroup != "Unknown")]
# shelter1.head()

# %% [markdown]
# ## Create a contingency table for both cats and dogs

# %%
shelter_crosstab = pd.crosstab(shelter['movementMonth'], shelter['movementtype'])
shelter_crosstab
# Out:
# movementtype     0     1
# movementMonth
# 1              369   793
# 2              330   530
# 3              428   538
# 4              592   538
# 5              822   697
# 6              885   897
# 7              977  1089
# 8              780  1296
# 9              773  1025
# 10             750  1091
# 11             550   932
# 12             405   977

# %% [markdown]
# ## Running the Independent Chi-Square for cats and dogs

# %%
stats.chi2_contingency(shelter_crosstab)
# Out:
# (387.42450111561885,
#  2.853267316015109e-76,
#  11,
#  array([[ 492.80790523,  669.19209477],
#         [ 364.72874225,  495.27125775],
#         [ 409.68368025,  556.31631975],
#         [ 479.23660319,  650.76339681],
#         [ 644.21274358,  874.78725642],
#         [ 755.7518822 , 1026.2481178 ],
#         [ 876.19718778, 1189.80281222],
#         [ 880.43821966, 1195.56178034],
#         [ 762.53753322, 1035.46246678],
#         [ 780.77397033, 1060.22602967],
#         [ 628.5209256 ,  853.4790744 ],
#         [ 586.11060673,  795.88939327]]))

# %% [markdown]
# ### The p value is < 0.5 and there is a significant relationship between months and movement types (adopted or not adopted) for both cats and dogs.

# %% [markdown]
# ## Test the Assumption of 5 Cases per Expected Cell
# ### All the values are over 5, so the assumption has been met.

# %% [markdown]
# ### Results: The month of August (8) has the highest rate of adoptions with 1296 adoptions total for both cats and dogs.

# %% [markdown]
# ## Create a contingency table for cats only

# %%
Cats = shelter[(shelter['speciesname'].isin(['Cat']))]
Cats
# Out:
#           id                       intakereason            breedname  \
# 0      15801                             Moving  Domestic Short Hair
# 4      30812                          Abandoned  Domestic Short Hair
# 5      30812                          Abandoned  Domestic Short Hair
# 11     46437                          Abandoned   Domestic Long Hair
# 12     46437                          Abandoned   Domestic Long Hair
# ...      ...                                ...                  ...
# 18054  72229                              Stray  Domestic Short Hair
# 18055  72230                              Stray  Domestic Short Hair
# 18056  72232  Incompatible with owner lifestyle   Domestic Long Hair
# 18057  72243                              Stray  Domestic Short Hair
# 18062  72260                             Moving  Domestic Short Hair
#
#       speciesname sexname  movementtype  intakeDate movementDate CatAgeGroup  \
# 0             Cat  Female             1  11/28/2009   05/13/2017      Senior
# 4             Cat  Female             0  01/11/2013   04/18/2017      Mature
# 5             Cat  Female             1  01/11/2013   05/29/2018      Mature
# 11            Cat  Female             0  10/26/2016   03/25/2017      Senior
# 12            Cat  Female             1  10/26/2016   04/07/2017      Senior
# ...           ...     ...           ...         ...          ...         ...
# 18054         Cat    Male             1  01/13/2022   01/21/2022      Kitten
# 18055         Cat  Female             1  01/13/2022   01/24/2022       Adult
# 18056         Cat    Male             1  01/13/2022   01/13/2022       Adult
# 18057         Cat    Male             1  01/14/2022   01/21/2022       Adult
# 18062         Cat  Female             0  01/18/2022   01/19/2022       Adult
#
#       DogAgeGroup  movementMonth  movementDay  movementYear  intakeMonth  \
# 0          Senior              5           13          2017           11
# 4          Senior              4           18          2017            1
# 5          Senior              5           29          2018            1
# 11      Geriatric              3           25          2017           10
# 12      Geriatric              4            7          2017           10
# ...           ...            ...          ...           ...          ...
# 18054       Puppy              1           21          2022            1
# 18055       Adult              1           24          2022            1
# 18056       Adult              1           13          2022            1
# 18057       Adult              1           21          2022            1
# 18062       Adult              1           19          2022            1
#
#        intakeDay  intakeYear
# 0             28        2009
# 4             11        2013
# 5             11        2013
# 11            26        2016
# 12            26        2016
# ...          ...         ...
# 18054         13        2022
# 18055         13        2022
# 18056         13        2022
# 18057         14        2022
# 18062         18        2022
#
# [11455 rows x 16 columns]

# %%
CatsCross = pd.crosstab(Cats['movementMonth'], Cats['movementtype'])
CatsCross
# Out:
# movementtype     0    1
# movementMonth
# 1              167  504
# 2              113  300
# 3              154  254
# 4              306  269
# 5              546  364
# 6              614  592
# 7              706  752
# 8              532  942
# 9              511  721
# 10             499  735
# 11             342  662
# 12             201  669

# %% [markdown]
# ## Running the Independent Chi-Square for cats only

# %%
stats.chi2_contingency(CatsCross)
# Out:
# (509.31573382018445,
#  3.3048804340577207e-102,
#  11,
#  array([[274.78489742, 396.21510258],
#         [169.12989961, 243.87010039],
#         [167.08232213, 240.91767787],
#         [235.47140986, 339.52859014],
#         [372.65910083, 537.34089917],
#         [493.87568747, 712.12431253],
#         [597.07359232, 860.92640768],
#         [603.62584024, 870.37415976],
#         [504.52309035, 727.47690965],
#         [505.34212134, 728.65787866],
#         [411.1535574 , 592.8464426 ],
#         [356.27848101, 513.72151899]]))

# %% [markdown]
# ### The p value is < 0.5 and there is a significant relationship between months and movement types (adopted or not adopted) for cats only.

# %% [markdown]
# ## Test the Assumption of 5 Cases per Expected Cell
# ### All the values are over 5, so the assumption has been met.

# %% [markdown]
# ### Results: The month of August (8) has the highest rate of adoptions with 942 adoptions total for cats only.

# %% [markdown]
# ## Create a contingency table for dogs only

# %%
Dogs = shelter[(shelter['speciesname'].isin(['Dog']))]
Dogs
# Out:
#           id                       intakereason  \
# 1      15932                             Moving
# 2      28859                          Abandoned
# 3      28859                          Abandoned
# 6      31469  Incompatible with owner lifestyle
# 7      31469  Incompatible with owner lifestyle
# ...      ...                                ...
# 18058  72245                              Stray
# 18059  72252                              Stray
# 18060  72253         Owner requested Euthanasia
# 18061  72253         Owner requested Euthanasia
# 18063  72285                    Landlord issues
#
#                                    breedname speciesname sexname  \
# 1                    German Shepherd Dog/Mix         Dog    Male
# 2                    Shep Mix/Siberian Husky         Dog  Female
# 3                    Shep Mix/Siberian Husky         Dog  Female
# 6                                Basenji/Mix         Dog  Female
# 7                                Basenji/Mix         Dog  Female
# ...                                      ...         ...     ...
# 18058  Australian Cattle Dog/Bully Breed Mix         Dog    Male
# 18059                                 Beagle         Dog  Female
# 18060                              Chihuahua         Dog  Female
# 18061                              Chihuahua         Dog  Female
# 18063                               Shih Tzu         Dog    Male
#
#        movementtype  intakeDate movementDate CatAgeGroup DogAgeGroup  \
# 1                 1  12/08/2009   04/24/2017      Mature      Senior
# 2                 1  08/10/2012   04/15/2017      Mature      Mature
# 3                 0  08/10/2012   02/29/2020      Mature      Mature
# 6                 1  03/26/2013   03/30/2013      Mature      Mature
# 7                 1  03/26/2013   05/09/2017      Mature      Mature
# ...             ...         ...          ...         ...         ...
# 18058             0  01/14/2022   01/15/2022  Adolescent  Adolescent
# 18059             0  01/15/2022   01/16/2022   Geriatric   Geriatric
# 18060             0  01/15/2022   01/20/2022   Geriatric   Geriatric
# 18061             1  01/15/2022   01/24/2022   Geriatric   Geriatric
# 18063             0  01/20/2022   01/20/2022  Adolescent  Adolescent
#
#        movementMonth  movementDay  movementYear  intakeMonth  intakeDay  \
# 1                  4           24          2017           12          8
# 2                  4           15          2017            8         10
# 3                  2           29          2020            8         10
# 6                  3           30          2013            3         26
# 7                  5            9          2017            3         26
# ...              ...          ...           ...          ...        ...
# 18058              1           15          2022            1         14
# 18059              1           16          2022            1         15
# 18060              1           20          2022            1         15
# 18061              1           24          2022            1         15
# 18063              1           20          2022            1         20
#
#        intakeYear
# 1            2009
# 2            2012
# 3            2012
# 6            2013
# 7            2013
# ...           ...
# 18058        2022
# 18059        2022
# 18060        2022
# 18061        2022
# 18063        2022
#
# [6609 rows x 16 columns]

# %%
DogsCross = pd.crosstab(Dogs['movementMonth'], Dogs['movementtype'])
DogsCross
# Out:
# movementtype     0    1
# movementMonth
# 1              202  289
# 2              217  230
# 3              274  284
# 4              286  269
# 5              276  333
# 6              271  305
# 7              271  337
# 8              248  354
# 9              262  304
# 10             251  356
# 11             208  270
# 12             204  308

# %% [markdown]
# ## Running the Independent Chi-Square for dogs only

# %%
stats.chi2_contingency(DogsCross)
# Out:
# (32.726284680260164,
#  0.0005826564501742283,
#  11,
#  array([[220.64911484, 270.35088516],
#         [200.87607808, 246.12392192],
#         [250.75805719, 307.24194281],
#         [249.4098956 , 305.5901044 ],
#         [273.67680436, 335.32319564],
#         [258.84702678, 317.15297322],
#         [273.22741716, 334.77258284],
#         [270.53109396, 331.46890604],
#         [254.35315479, 311.64684521],
#         [272.77802996, 334.22197004],
#         [214.80708125, 263.19291875],
#         [230.08624603, 281.91375397]]))

# %% [markdown]
# ### The p value is < 0.5 and there is a significant relationship between months and movement types (adopted or not adopted) for dogs only.

# %% [markdown]
# ## Test the Assumption of 5 Cases per Expected Cell
# ### All the values are over 5, so the assumption has been met.

# %% [markdown]
# ### Results: The months of August (8) and October (10) have the highest rate of adoptions with 354 and 356 adoptions respectively for dogs only.

# %%
# shelter1.to_csv(r'C:\Users\ardit\Desktop\python_course\Final Project\ShelterFinal.csv', index = False)
