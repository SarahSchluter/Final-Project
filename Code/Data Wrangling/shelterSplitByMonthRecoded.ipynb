# %% [markdown]
# # import packages

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels
import scipy
from scipy import stats
from scipy.stats import boxcox
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison
from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.proportion import proportions_chisquare
from sklearn.metrics import ConfusionMatrixDisplay

# %% [markdown]
# # read in data

# %%
shelterSplitByMonth=pd.read_csv("C:/Users/hazre/OneDrive/OneNote/GitHub/Final-Project/shelterSplitByMonth.csv")

# %%
shelterSplitByMonth.head()
# Out:
#       id intakereason   animalname                breedname  \
# 0  15801       Moving       Jadzia      Domestic Short Hair
# 1  15932       Moving        Gonzo  German Shepherd Dog/Mix
# 2  28859    Abandoned       Maggie  Shep Mix/Siberian Husky
# 3  28859    Abandoned       Maggie  Shep Mix/Siberian Husky
# 4  30812    Abandoned  Pretty Girl      Domestic Short Hair
#
#              basecolour speciesname           animalage sexname movementtype  \
# 0         Tortoiseshell         Cat  11 years 8 months.  Female     Adoption
# 1                   Tan         Dog  10 years 9 months.    Male     Adoption
# 2               Various         Dog    8 years 1 month.  Female     Adoption
# 3               Various         Dog    8 years 1 month.  Female    Reclaimed
# 4  Dilute tortoiseshell         Cat  10 years 6 months.  Female       Foster
#
#    intakeDate movementDate CatAgeGroup DogAgeGroup  movementMonth  \
# 0  11/28/2009   05/13/2017      Senior      Senior              5
# ...

# %% [markdown]
# ## recode intakeMonth to reflect month names

# %%
shelterSplitByMonth.intakeMonth.value_counts()
# Out:
# 6     2193
# 7     2152
# 5     2068
# 9     1935
# 8     1812
# 10    1762
# 4     1300
# 11    1242
# 3     1037
# 12    1014
# 1      902
# 2      891
# Name: intakeMonth, dtype: int64

# %%
def intakeMonthR (series):
    if series == 1:
        return "January"
    if series -- 2:
        return "February"
    if series == 3:
        return "March"
    if series == 4:
        return "April"
    if series == 5:
        return "May"
    if series == 6:
        return "June"
    if series == 7:
        return "July"
    if series == 8:
        return "August"
    if series == 9:
        return "September"
    if series == 10:
        return "October"
    if series == 11:
        return "November"
    if series == 12:
        return December
shelterSplitByMonth["intakeMonthR"]= shelterSplitByMonth["intakeMonth"].apply(intakeMonthR)

# %%
shelterSplitByMonth.head()
# Out:
#       id intakereason   animalname                breedname  \
# 0  15801       Moving       Jadzia      Domestic Short Hair
# 1  15932       Moving        Gonzo  German Shepherd Dog/Mix
# 2  28859    Abandoned       Maggie  Shep Mix/Siberian Husky
# 3  28859    Abandoned       Maggie  Shep Mix/Siberian Husky
# 4  30812    Abandoned  Pretty Girl      Domestic Short Hair
#
#              basecolour speciesname           animalage sexname movementtype  \
# 0         Tortoiseshell         Cat  11 years 8 months.  Female     Adoption
# 1                   Tan         Dog  10 years 9 months.    Male     Adoption
# 2               Various         Dog    8 years 1 month.  Female     Adoption
# 3               Various         Dog    8 years 1 month.  Female    Reclaimed
# 4  Dilute tortoiseshell         Cat  10 years 6 months.  Female       Foster
#
#    intakeDate movementDate CatAgeGroup DogAgeGroup  movementMonth  \
# 0  11/28/2009   05/13/2017      Senior      Senior              5
# ...
