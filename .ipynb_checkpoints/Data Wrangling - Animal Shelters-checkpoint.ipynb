# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels
import scipy
from scipy import stats
from scipy.stats import boxcox
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison
from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.proportion import proportions_chisquare
from sklearn.metrics import ConfusionMatrixDisplay

# %% [markdown]
# # Read in Data

# %%
shelter = pd.read_csv(r'Animal_Shelter_Animals.csv')
pd.set_option('display.max_columns', None)
shelter.head()
# Out:
#       id              intakedate intakereason  istransfer sheltercode  \
# 0  15801  11/28/2009 12:00:00 AM       Moving       False   C09115463
# 1  15932  12/08/2009 12:00:00 AM       Moving       False   D09125594
# 2  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 3  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 4  30812  01/11/2013 12:00:00 AM    Abandoned       False    C1301091
#
#   identichipnumber   animalname                breedname  \
# 0       0A115D7358       Jadzia      Domestic Short Hair
# 1       0A11675477        Gonzo  German Shepherd Dog/Mix
# 2       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 3       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 4       0A13403D4D  Pretty Girl      Domestic Short Hair
#
#              basecolour speciesname           animalage sexname  \
# 0         Tortoiseshell         Cat  11 years 8 months.  Female
# 1                   Tan         Dog  10 years 9 months.    Male
# 2               Various         Dog    8 years 1 month.  Female
# 3               Various         Dog    8 years 1 month.  Female
# 4  Dilute tortoiseshell         Cat  10 years 6 months.  Female
#
#                      location            movementdate movementtype  istrial  \
# 0  Adoptable Cat Glass Colony  05/13/2017 12:00:00 AM     Adoption    False
# 1              Adoptable Dogs  04/24/2017 12:00:00 AM     Adoption    False
# 2          Canine intake room  04/15/2017 12:00:00 AM     Adoption    False
# 3          Canine intake room  02/29/2020 12:00:00 AM    Reclaimed    False
# 4                  Stray Cats  04/18/2017 12:00:00 AM       Foster    False
#
#                returndate returnedreason deceaseddate deceasedreason  \
# 0                     NaN          Stray          NaN   Died in care
# 1                     NaN          Stray          NaN   Died in care
# 2  02/28/2020 12:00:00 AM          Stray          NaN   Died in care
# 3                     NaN          Stray          NaN   Died in care
# 4  05/29/2018 12:00:00 AM          Stray          NaN   Died in care
#
#    diedoffshelter  puttosleep  isdoa
# 0           False       False  False
# 1           False       False  False
# 2           False       False  False
# 3           False       False  False
# 4           False       False  False

# %% [markdown]
# # Check Data Types

# %%
shelter.dtypes
# Out:
# id                   int64
# intakedate          object
# intakereason        object
# istransfer            bool
# sheltercode         object
# identichipnumber    object
# animalname          object
# breedname           object
# basecolour          object
# speciesname         object
# animalage           object
# sexname             object
# location            object
# movementdate        object
# movementtype        object
# istrial               bool
# returndate          object
# returnedreason      object
# deceaseddate        object
# deceasedreason      object
# diedoffshelter        bool
# puttosleep            bool
# isdoa                 bool
# animalage_years      int64
# dtype: object

# %% [markdown]
# ## View the sum of unique values in movementtype

# %%
shelter.movementtype.value_counts()
# Out:
# Adoption            11105
# Foster               4984
# Reclaimed            2485
# Transfer              711
# None                   61
# Released To Wild       36
# Escaped                 9
# Stolen                  8
# Name: movementtype, dtype: int64

# %%
shelter.speciesname.value_counts()
# Out:
# Cat                 11708
# Dog                  6661
# House Rabbit          353
# Guinea Pig            190
# Rat                   165
# Bird                   80
# Livestock              40
# Hamster                26
# Mouse                  20
# Hedgehog               18
# Gerbil                 18
# Snake                  14
# Ferret                 14
# Wildlife - other       14
# Pig                    13
# Lizard                 13
# Chicken                10
# Turtle                  8
# Sugar Glider            7
# Opossum                 6
# Fish                    6
# Goat                    5
# Chinchilla              4
# Tortoise                3
# Raccoon                 1
# Squirrel                1
# Tarantula               1
# Name: speciesname, dtype: int64

# %%
Cat = shelter.query('speciesname == "Cat"')
Cat.head()
# Out:
#        id              intakedate intakereason  istransfer sheltercode  \
# 0   15801  11/28/2009 12:00:00 AM       Moving       False   C09115463
# 4   30812  01/11/2013 12:00:00 AM    Abandoned       False    C1301091
# 5   30812  01/11/2013 12:00:00 AM    Abandoned       False    C1301091
# 13  46437  10/26/2016 12:00:00 AM    Abandoned       False   C16103406
# 14  46437  10/26/2016 12:00:00 AM    Abandoned       False   C16103406
#
#    identichipnumber   animalname            breedname            basecolour  \
# 0        0A115D7358       Jadzia  Domestic Short Hair         Tortoiseshell
# 4        0A13403D4D  Pretty Girl  Domestic Short Hair  Dilute tortoiseshell
# 5        0A13403D4D  Pretty Girl  Domestic Short Hair  Dilute tortoiseshell
# 13  981020017650993         Nova   Domestic Long Hair                 Black
# 14  981020017650993         Nova   Domestic Long Hair                 Black
#
#    speciesname           animalage sexname                    location  \
# 0          Cat  11 years 8 months.  Female  Adoptable Cat Glass Colony
# 4          Cat  10 years 6 months.  Female                  Stray Cats
# 5          Cat  10 years 6 months.  Female                  Stray Cats
# 13         Cat  12 years 3 months.  Female                  Stray Cats
# 14         Cat  12 years 3 months.  Female                  Stray Cats
#
#               movementdate movementtype  istrial              returndate  \
# 0   05/13/2017 12:00:00 AM     Adoption    False                     NaN
# 4   04/18/2017 12:00:00 AM       Foster    False  05/29/2018 12:00:00 AM
# 5   05/29/2018 12:00:00 AM     Adoption    False                     NaN
# 13  03/25/2017 12:00:00 AM       Foster    False  04/07/2017 12:00:00 AM
# 14  04/07/2017 12:00:00 AM     Adoption    False  02/09/2018 12:00:00 AM
#
#                        returnedreason            deceaseddate  \
# 0                               Stray                     NaN
# 4                               Stray                     NaN
# 5                               Stray                     NaN
# 13                              Stray  02/10/2018 12:00:00 AM
# 14  Incompatible with owner lifestyle  02/10/2018 12:00:00 AM
#
#                            deceasedreason  diedoffshelter  puttosleep  isdoa  \
# 0                            Died in care           False       False  False
# 4                            Died in care           False       False  False
# 5                            Died in care           False       False  False
# 13  UU - untreatable, unmanageable health           False        True  False
# 14  UU - untreatable, unmanageable health           False        True  False
#
#     animalage_years
# 0                11
# 4                10
# 5                10
# 13               12
# 14               12

# %%
Cat.shape
# Out:
# (11708, 24)

# %%
Dog = shelter.query('speciesname == "Dog"')
Dog.shape
# Out:
# (6661, 24)

# %% [markdown]
# ## Bar graph of movementtypes

# %%
plt.title('Movement Type')
shelter['movementtype'].value_counts().nlargest(5).plot.bar()
# Out:
# <AxesSubplot:title={'center':'Movement Type'}>

# %% [markdown]
# # Data Wrangling
# ## Split animal age into years only

# %%
shelter['animalage_years'] = shelter['animalage'].apply(lambda x: int(x.split()[0]))

# %%
shelter.head()
# Out:
#       id              intakedate intakereason  istransfer sheltercode  \
# 0  15801  11/28/2009 12:00:00 AM       Moving       False   C09115463
# 1  15932  12/08/2009 12:00:00 AM       Moving       False   D09125594
# 2  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 3  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 4  30812  01/11/2013 12:00:00 AM    Abandoned       False    C1301091
#
#   identichipnumber   animalname                breedname  \
# 0       0A115D7358       Jadzia      Domestic Short Hair
# 1       0A11675477        Gonzo  German Shepherd Dog/Mix
# 2       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 3       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 4       0A13403D4D  Pretty Girl      Domestic Short Hair
#
#              basecolour speciesname           animalage sexname  \
# 0         Tortoiseshell         Cat  11 years 8 months.  Female
# 1                   Tan         Dog  10 years 9 months.    Male
# 2               Various         Dog    8 years 1 month.  Female
# 3               Various         Dog    8 years 1 month.  Female
# 4  Dilute tortoiseshell         Cat  10 years 6 months.  Female
#
#                      location            movementdate movementtype  istrial  \
# 0  Adoptable Cat Glass Colony  05/13/2017 12:00:00 AM     Adoption    False
# 1              Adoptable Dogs  04/24/2017 12:00:00 AM     Adoption    False
# 2          Canine intake room  04/15/2017 12:00:00 AM     Adoption    False
# 3          Canine intake room  02/29/2020 12:00:00 AM    Reclaimed    False
# 4                  Stray Cats  04/18/2017 12:00:00 AM       Foster    False
#
#                returndate returnedreason deceaseddate deceasedreason  \
# 0                     NaN          Stray          NaN   Died in care
# 1                     NaN          Stray          NaN   Died in care
# 2  02/28/2020 12:00:00 AM          Stray          NaN   Died in care
# 3                     NaN          Stray          NaN   Died in care
# 4  05/29/2018 12:00:00 AM          Stray          NaN   Died in care
#
#    diedoffshelter  puttosleep  isdoa  animalage_years
# 0           False       False  False               11
# 1           False       False  False               10
# 2           False       False  False                8
# 3           False       False  False                8
# 4           False       False  False               10

# %%
variable1 = shelter.groupby('speciesname')
variable1 = variable1.count()
variable1 = variable1.sort_values(['animalage_years'], ascending=False)

# %%
variable1.head()
# Out:
#                  id  intakedate  intakereason  istransfer  sheltercode  \
# speciesname
# Cat           11708       11708         11707       11708        11708
# Dog            6661        6661          6661        6661         6661
# House Rabbit    353         353           352         353          353
# Guinea Pig      190         190           190         190          190
# Rat             165         165           165         165          165
#
#               identichipnumber  animalname  breedname  basecolour  animalage  \
# speciesname
# Cat                      10676       11708      11708       11708      11708
# Dog                       5674        6661       6660        6661       6661
# House Rabbit                 2         353        353         353        353
# Guinea Pig                   0         190        186         190        190
# Rat                          0         165        165         165        165
#
#               sexname  location  movementdate  movementtype  istrial  \
# speciesname
# Cat             11708     11708         11653         11708    11708
# Dog              6661      6661          6657          6661     6661
# House Rabbit      353       353           353           353      353
# Guinea Pig        190       190           190           190      190
# Rat               165       165           165           165      165
#
#               returndate  returnedreason  deceaseddate  deceasedreason  \
# speciesname
# Cat                 4411           11708           347           11708
# Dog                 2124            6661           187            6661
# House Rabbit          89             353             3             353
# Guinea Pig            19             190             0             190
# Rat                    9             165             0             165
#
#               diedoffshelter  puttosleep  isdoa  animalage_years
# speciesname
# Cat                    11708       11708  11708            11708
# Dog                     6661        6661   6661             6661
# House Rabbit             353         353    353              353
# Guinea Pig               190         190    190              190
# Rat                      165         165    165              165

# %% [markdown]
# ## Split Dates and Remove Time

# %%
shelter1 = shelter['intakedate'].str.split(' ', expand = True).rename(columns = lambda x: "intakedate"+str(x+1))

# %%
shelter1.head()
# Out:
#   intakedate1 intakedate2 intakedate3
# 0  11/28/2009    12:00:00          AM
# 1  12/08/2009    12:00:00          AM
# 2  08/10/2012    12:00:00          AM
# 3  08/10/2012    12:00:00          AM
# 4  01/11/2013    12:00:00          AM

# %%
shelter2 = shelter['movementdate'].str.split(' ', expand = True).rename(columns = lambda x: "movementDate"+str(x+1))

# %%
shelter2.head()
# Out:
#   movementDate1 movementDate2 movementDate3
# 0    05/13/2017      12:00:00            AM
# 1    04/24/2017      12:00:00            AM
# 2    04/15/2017      12:00:00            AM
# 3    02/29/2020      12:00:00            AM
# 4    04/18/2017      12:00:00            AM

# %%
shelter3 = shelter['returndate'].str.split(' ', expand = True).rename(columns = lambda x: "returndate"+str(x+1))

# %%
shelter3.head()
# Out:
#   returndate1 returndate2 returndate3
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2  02/28/2020    12:00:00          AM
# 3         NaN         NaN         NaN
# 4  05/29/2018    12:00:00          AM

# %%
shelter4 = shelter['deceaseddate'].str.split(' ', expand = True).rename(columns = lambda x: "deceaseddate"+str(x+1))

# %%
shelter4.head()
# Out:
#   deceaseddate1 deceaseddate2 deceaseddate3
# 0           NaN           NaN           NaN
# 1           NaN           NaN           NaN
# 2           NaN           NaN           NaN
# 3           NaN           NaN           NaN
# 4           NaN           NaN           NaN

# %% [markdown]
# ## Add split columns back and rename date-only columns

# %%
shelter5 = pd.concat([shelter, shelter1, shelter2, shelter3, shelter4], axis = 1)

# %%
shelter5.head()
# Out:
#       id              intakedate intakereason  istransfer sheltercode  \
# 0  15801  11/28/2009 12:00:00 AM       Moving       False   C09115463
# 1  15932  12/08/2009 12:00:00 AM       Moving       False   D09125594
# 2  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 3  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 4  30812  01/11/2013 12:00:00 AM    Abandoned       False    C1301091
#
#   identichipnumber   animalname                breedname  \
# 0       0A115D7358       Jadzia      Domestic Short Hair
# 1       0A11675477        Gonzo  German Shepherd Dog/Mix
# 2       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 3       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 4       0A13403D4D  Pretty Girl      Domestic Short Hair
#
#              basecolour speciesname           animalage sexname  \
# 0         Tortoiseshell         Cat  11 years 8 months.  Female
# 1                   Tan         Dog  10 years 9 months.    Male
# 2               Various         Dog    8 years 1 month.  Female
# 3               Various         Dog    8 years 1 month.  Female
# 4  Dilute tortoiseshell         Cat  10 years 6 months.  Female
#
#                      location            movementdate movementtype  istrial  \
# 0  Adoptable Cat Glass Colony  05/13/2017 12:00:00 AM     Adoption    False
# 1              Adoptable Dogs  04/24/2017 12:00:00 AM     Adoption    False
# 2          Canine intake room  04/15/2017 12:00:00 AM     Adoption    False
# 3          Canine intake room  02/29/2020 12:00:00 AM    Reclaimed    False
# 4                  Stray Cats  04/18/2017 12:00:00 AM       Foster    False
#
#                returndate returnedreason deceaseddate deceasedreason  \
# 0                     NaN          Stray          NaN   Died in care
# 1                     NaN          Stray          NaN   Died in care
# 2  02/28/2020 12:00:00 AM          Stray          NaN   Died in care
# 3                     NaN          Stray          NaN   Died in care
# 4  05/29/2018 12:00:00 AM          Stray          NaN   Died in care
#
#    diedoffshelter  puttosleep  isdoa  animalage_years intakedate1 intakedate2  \
# 0           False       False  False               11  11/28/2009    12:00:00
# 1           False       False  False               10  12/08/2009    12:00:00
# 2           False       False  False                8  08/10/2012    12:00:00
# 3           False       False  False                8  08/10/2012    12:00:00
# 4           False       False  False               10  01/11/2013    12:00:00
#
#   intakedate3 movementDate1 movementDate2 movementDate3 returndate1  \
# 0          AM    05/13/2017      12:00:00            AM         NaN
# 1          AM    04/24/2017      12:00:00            AM         NaN
# 2          AM    04/15/2017      12:00:00            AM  02/28/2020
# 3          AM    02/29/2020      12:00:00            AM         NaN
# 4          AM    04/18/2017      12:00:00            AM  05/29/2018
#
#   returndate2 returndate3 deceaseddate1 deceaseddate2 deceaseddate3
# 0         NaN         NaN           NaN           NaN           NaN
# 1         NaN         NaN           NaN           NaN           NaN
# 2    12:00:00          AM           NaN           NaN           NaN
# 3         NaN         NaN           NaN           NaN           NaN
# 4    12:00:00          AM           NaN           NaN           NaN

# %%
shelter5.drop(['intakedate', 'movementdate', 'returndate', 'deceaseddate'], axis=1, inplace=True)

# %%
shelter5.rename(columns={'intakedate1' : 'intakedate', 'movementDate1' : 'movementDate', 'returndate1' : 'returndate',
                        'deceaseddate1' : 'deceaseddate'}, inplace=True)

# %%
shelter5.head()
# Out:
#       id intakereason  istransfer sheltercode identichipnumber   animalname  \
# 0  15801       Moving       False   C09115463       0A115D7358       Jadzia
# 1  15932       Moving       False   D09125594       0A11675477        Gonzo
# 2  28859    Abandoned       False   D12082309       0A13253C7B       Maggie
# 3  28859    Abandoned       False   D12082309       0A13253C7B       Maggie
# 4  30812    Abandoned       False    C1301091       0A13403D4D  Pretty Girl
#
#                  breedname            basecolour speciesname  \
# 0      Domestic Short Hair         Tortoiseshell         Cat
# 1  German Shepherd Dog/Mix                   Tan         Dog
# 2  Shep Mix/Siberian Husky               Various         Dog
# 3  Shep Mix/Siberian Husky               Various         Dog
# 4      Domestic Short Hair  Dilute tortoiseshell         Cat
#
#             animalage sexname                    location movementtype  \
# 0  11 years 8 months.  Female  Adoptable Cat Glass Colony     Adoption
# 1  10 years 9 months.    Male              Adoptable Dogs     Adoption
# 2    8 years 1 month.  Female          Canine intake room     Adoption
# 3    8 years 1 month.  Female          Canine intake room    Reclaimed
# 4  10 years 6 months.  Female                  Stray Cats       Foster
#
#    istrial returnedreason deceasedreason  diedoffshelter  puttosleep  isdoa  \
# 0    False          Stray   Died in care           False       False  False
# 1    False          Stray   Died in care           False       False  False
# 2    False          Stray   Died in care           False       False  False
# 3    False          Stray   Died in care           False       False  False
# 4    False          Stray   Died in care           False       False  False
#
#    animalage_years  intakedate intakedate2 intakedate3 movementDate  \
# 0               11  11/28/2009    12:00:00          AM   05/13/2017
# 1               10  12/08/2009    12:00:00          AM   04/24/2017
# 2                8  08/10/2012    12:00:00          AM   04/15/2017
# 3                8  08/10/2012    12:00:00          AM   02/29/2020
# 4               10  01/11/2013    12:00:00          AM   04/18/2017
#
#   movementDate2 movementDate3  returndate returndate2 returndate3  \
# 0      12:00:00            AM         NaN         NaN         NaN
# 1      12:00:00            AM         NaN         NaN         NaN
# 2      12:00:00            AM  02/28/2020    12:00:00          AM
# 3      12:00:00            AM         NaN         NaN         NaN
# 4      12:00:00            AM  05/29/2018    12:00:00          AM
#
#   deceaseddate deceaseddate2 deceaseddate3
# 0          NaN           NaN           NaN
# 1          NaN           NaN           NaN
# 2          NaN           NaN           NaN
# 3          NaN           NaN           NaN
# 4          NaN           NaN           NaN

# %%
shelter5.drop(['intakedate2', 'intakedate3', 'movementDate2', 'movementDate3', 'returndate2', 'returndate3', 
               'deceaseddate2', 'deceaseddate3', 'istrial', 'istransfer', 'diedoffshelter', 'isdoa'], axis=1, inplace=True)

# %%
shelter5.head()
# Out:
#       id intakereason sheltercode identichipnumber   animalname  \
# 0  15801       Moving   C09115463       0A115D7358       Jadzia
# 1  15932       Moving   D09125594       0A11675477        Gonzo
# 2  28859    Abandoned   D12082309       0A13253C7B       Maggie
# 3  28859    Abandoned   D12082309       0A13253C7B       Maggie
# 4  30812    Abandoned    C1301091       0A13403D4D  Pretty Girl
#
#                  breedname            basecolour speciesname  \
# 0      Domestic Short Hair         Tortoiseshell         Cat
# 1  German Shepherd Dog/Mix                   Tan         Dog
# 2  Shep Mix/Siberian Husky               Various         Dog
# 3  Shep Mix/Siberian Husky               Various         Dog
# 4      Domestic Short Hair  Dilute tortoiseshell         Cat
#
#             animalage sexname                    location movementtype  \
# 0  11 years 8 months.  Female  Adoptable Cat Glass Colony     Adoption
# 1  10 years 9 months.    Male              Adoptable Dogs     Adoption
# 2    8 years 1 month.  Female          Canine intake room     Adoption
# 3    8 years 1 month.  Female          Canine intake room    Reclaimed
# 4  10 years 6 months.  Female                  Stray Cats       Foster
#
#   returnedreason deceasedreason  puttosleep  animalage_years  intakedate  \
# 0          Stray   Died in care       False               11  11/28/2009
# 1          Stray   Died in care       False               10  12/08/2009
# 2          Stray   Died in care       False                8  08/10/2012
# 3          Stray   Died in care       False                8  08/10/2012
# 4          Stray   Died in care       False               10  01/11/2013
#
#   movementDate  returndate deceaseddate
# 0   05/13/2017         NaN          NaN
# 1   04/24/2017         NaN          NaN
# 2   04/15/2017  02/28/2020          NaN
# 3   02/29/2020         NaN          NaN
# 4   04/18/2017  05/29/2018          NaN

# %%
shelter.tail(15)
# Out:
#           id              intakedate                       intakereason  \
# 19384  72227  01/12/2022 03:29:05 PM                              Stray
# 19385  72229  01/13/2022 09:56:31 AM                              Stray
# 19386  72230  01/13/2022 10:37:47 AM                              Stray
# 19387  72232  01/13/2022 12:43:18 PM  Incompatible with owner lifestyle
# 19388  72233  01/13/2022 01:20:50 PM                              Stray
# 19389  72234  01/13/2022 02:34:34 PM                             Moving
# 19390  72235  01/13/2022 02:36:11 PM                             Moving
# 19391  72243  01/14/2022 08:41:06 AM                              Stray
# 19392  72245  01/14/2022 10:24:03 AM                              Stray
# 19393  72252  01/15/2022 10:06:40 AM                              Stray
# 19394  72253  01/15/2022 01:32:03 PM         Owner requested Euthanasia
# 19395  72253  01/15/2022 01:32:03 PM         Owner requested Euthanasia
# 19396  72260  01/18/2022 12:29:00 PM                             Moving
# 19397  72285  01/20/2022 03:00:35 PM                    Landlord issues
# 19398  72285  01/20/2022 03:00:35 PM                    Landlord issues
#
#        istransfer sheltercode identichipnumber animalname  \
# 19384       False    C2201041  981020045525787     Murray
# 19385       False    C2201039  981020045526356       Kuro
# 19386       False    C2201040  981020045536015     Tiptoe
# 19387       False    C2201042  981020045230711       Loki
# 19388       False    H2201042              NaN  stray bun
# 19389       False    G2201043              NaN      Sandy
# 19390       False    G2201044              NaN       Oreo
# 19391       False    C2201046  981020045532583      Butch
# 19392       False    D2201044  982091063915522      Bruno
# 19393       False    D2201051              NaN      Chloe
# 19394       False    D2201031  981020045514201    Twinkie
# 19395       False    D2201031  981020045514201    Twinkie
# 19396       False    C2201051  982000364969782      Ariel
# 19397       False    D2201071              NaN       Duke
# 19398       False    D2201071              NaN       Duke
#
#                                    breedname              basecolour  \
# 19384                    Domestic Short Hair         Black and White
# 19385                    Domestic Short Hair         Black and White
# 19386                    Domestic Short Hair                  Calico
# 19387                     Domestic Long Hair          Grey and White
# 19388                               American         Black and White
# 19389                             Guinea Pig                   Brown
# 19390                             Guinea Pig               Tricolour
# 19391                    Domestic Short Hair                  Orange
# 19392  Australian Cattle Dog/Bully Breed Mix         White and Liver
# 19393                                 Beagle         White and Black
# 19394                              Chihuahua           Tan and White
# 19395                              Chihuahua           Tan and White
# 19396                    Domestic Short Hair                   Black
# 19397                               Shih Tzu  Brown, Black and White
# 19398                               Shih Tzu  Brown, Black and White
#
#         speciesname           animalage  sexname                  location  \
# 19384           Cat           20 weeks.     Male     Adoptable Cat Kennels
# 19385           Cat           18 weeks.     Male   Adoptable window colony
# 19386           Cat   2 years 0 months.   Female  Adoptable Cat Big Colony
# 19387           Cat   3 years 0 months.     Male     Adoptable Cat Kennels
# 19388  House Rabbit   99 years 1 month.  Unknown        Feline intake room
# 19389    Guinea Pig    1 year 0 months.   Female         Small Animal room
# 19390    Guinea Pig    1 year 0 months.   Female         Small Animal room
# 19391           Cat   3 years 0 months.     Male  Adoptable Cat Big Colony
# 19392           Dog   1 year 11 months.     Male                Dog room C
# 19393           Dog  16 years 0 months.   Female                Dog room A
# 19394           Dog  17 years 0 months.   Female                Dog room D
# 19395           Dog  17 years 0 months.   Female                Dog room D
# 19396           Cat   4 years 0 months.   Female                Cat room C
# 19397           Dog    1 year 9 months.     Male                Dog room A
# 19398           Dog    1 year 9 months.     Male                Dog room A
#
#                  movementdate movementtype  istrial              returndate  \
# 19384  01/23/2022 12:00:00 AM     Adoption    False                     NaN
# 19385  01/21/2022 12:00:00 AM     Adoption    False                     NaN
# 19386  01/24/2022 12:00:00 AM     Adoption    False                     NaN
# 19387  01/13/2022 12:00:00 AM     Adoption    False                     NaN
# 19388  01/13/2022 12:00:00 AM       Foster    False                     NaN
# 19389  01/22/2022 12:00:00 AM     Adoption    False                     NaN
# 19390  01/22/2022 12:00:00 AM     Adoption    False                     NaN
# 19391  01/21/2022 12:00:00 AM     Adoption    False                     NaN
# 19392  01/15/2022 12:00:00 AM    Reclaimed    False                     NaN
# 19393  01/16/2022 12:00:00 AM    Reclaimed    False                     NaN
# 19394  01/20/2022 12:00:00 AM       Foster    False  01/24/2022 12:00:00 AM
# 19395  01/24/2022 12:00:00 AM     Adoption    False                     NaN
# 19396  01/19/2022 12:00:00 AM     Transfer    False                     NaN
# 19397  01/20/2022 12:00:00 AM       Foster    False                     NaN
# 19398                     NaN         None    False                     NaN
#
#       returnedreason deceaseddate      deceasedreason  diedoffshelter  \
# 19384          Stray          NaN  Court Order/ Legal           False
# 19385          Stray          NaN  Court Order/ Legal           False
# 19386          Stray          NaN  Court Order/ Legal           False
# 19387          Stray          NaN  Court Order/ Legal           False
# 19388          Stray          NaN  Court Order/ Legal           False
# 19389          Stray          NaN  Court Order/ Legal           False
# 19390          Stray          NaN  Court Order/ Legal           False
# 19391          Stray          NaN  Court Order/ Legal           False
# 19392          Stray          NaN  Court Order/ Legal           False
# 19393          Stray          NaN  Court Order/ Legal           False
# 19394          Stray          NaN  Court Order/ Legal           False
# 19395          Stray          NaN  Court Order/ Legal           False
# 19396          Stray          NaN  Court Order/ Legal           False
# 19397          Stray          NaN  Court Order/ Legal           False
# 19398          Stray          NaN  Court Order/ Legal           False
#
#        puttosleep  isdoa  animalage_years
# 19384       False  False               20
# 19385       False  False               18
# 19386       False  False                2
# 19387       False  False                3
# 19388       False  False               99
# 19389       False  False                1
# 19390       False  False                1
# 19391       False  False                3
# 19392       False  False                1
# 19393       False  False               16
# 19394       False  False               17
# 19395       False  False               17
# 19396       False  False                4
# 19397       False  False                1
# 19398       False  False                1
