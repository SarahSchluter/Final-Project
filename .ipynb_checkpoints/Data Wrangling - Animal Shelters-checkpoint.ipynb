# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels
import scipy
from scipy import stats
from scipy.stats import boxcox
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison
from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.proportion import proportions_chisquare
from sklearn.metrics import ConfusionMatrixDisplay

# %%
shelter = pd.read_csv(r'D:\Entity Academy\Final Project\Week 1 Project Planning\Animal_Shelter_Animals.csv')
pd.set_option('display.max_columns', None)
shelter.head()
# Out:
#       id              intakedate intakereason  istransfer sheltercode  \
# 0  15801  11/28/2009 12:00:00 AM       Moving       False   C09115463
# 1  15932  12/08/2009 12:00:00 AM       Moving       False   D09125594
# 2  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 3  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 4  30812  01/11/2013 12:00:00 AM    Abandoned       False    C1301091
#
#   identichipnumber   animalname                breedname  \
# 0       0A115D7358       Jadzia      Domestic Short Hair
# 1       0A11675477        Gonzo  German Shepherd Dog/Mix
# 2       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 3       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 4       0A13403D4D  Pretty Girl      Domestic Short Hair
#
#              basecolour speciesname           animalage sexname  \
# 0         Tortoiseshell         Cat  11 years 8 months.  Female
# 1                   Tan         Dog  10 years 9 months.    Male
# 2               Various         Dog    8 years 1 month.  Female
# 3               Various         Dog    8 years 1 month.  Female
# 4  Dilute tortoiseshell         Cat  10 years 6 months.  Female
#
#                      location            movementdate movementtype  istrial  \
# 0  Adoptable Cat Glass Colony  05/13/2017 12:00:00 AM     Adoption    False
# 1              Adoptable Dogs  04/24/2017 12:00:00 AM     Adoption    False
# 2          Canine intake room  04/15/2017 12:00:00 AM     Adoption    False
# 3          Canine intake room  02/29/2020 12:00:00 AM    Reclaimed    False
# 4                  Stray Cats  04/18/2017 12:00:00 AM       Foster    False
#
#                returndate returnedreason deceaseddate deceasedreason  \
# 0                     NaN          Stray          NaN   Died in care
# 1                     NaN          Stray          NaN   Died in care
# 2  02/28/2020 12:00:00 AM          Stray          NaN   Died in care
# 3                     NaN          Stray          NaN   Died in care
# 4  05/29/2018 12:00:00 AM          Stray          NaN   Died in care
#
#    diedoffshelter  puttosleep  isdoa
# 0           False       False  False
# 1           False       False  False
# 2           False       False  False
# 3           False       False  False
# 4           False       False  False

# %%
shelter.describe()
# Out:
#                  id  animalage_years
# count  19327.000000     19327.000000
# mean   63455.185078         5.404719
# std     5085.697673         9.069284
# min    15801.000000         0.000000
# 25%    59486.500000         2.000000
# 50%    63543.000000         3.000000
# 75%    67656.000000         8.000000
# max    72252.000000       972.000000

# %%
shelter['animalage_years'] = shelter['animalage'].apply(lambda x: int(x.split()[0]))

# %%
shelter.head()
# Out:
#       id              intakedate intakereason  istransfer sheltercode  \
# 0  15801  11/28/2009 12:00:00 AM       Moving       False   C09115463
# 1  15932  12/08/2009 12:00:00 AM       Moving       False   D09125594
# 2  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 3  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 4  30812  01/11/2013 12:00:00 AM    Abandoned       False    C1301091
#
#   identichipnumber   animalname                breedname  \
# 0       0A115D7358       Jadzia      Domestic Short Hair
# 1       0A11675477        Gonzo  German Shepherd Dog/Mix
# 2       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 3       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 4       0A13403D4D  Pretty Girl      Domestic Short Hair
#
#              basecolour speciesname           animalage sexname  \
# 0         Tortoiseshell         Cat  11 years 8 months.  Female
# 1                   Tan         Dog  10 years 9 months.    Male
# 2               Various         Dog    8 years 1 month.  Female
# 3               Various         Dog    8 years 1 month.  Female
# 4  Dilute tortoiseshell         Cat  10 years 6 months.  Female
#
#                      location            movementdate movementtype  istrial  \
# 0  Adoptable Cat Glass Colony  05/13/2017 12:00:00 AM     Adoption    False
# 1              Adoptable Dogs  04/24/2017 12:00:00 AM     Adoption    False
# 2          Canine intake room  04/15/2017 12:00:00 AM     Adoption    False
# 3          Canine intake room  02/29/2020 12:00:00 AM    Reclaimed    False
# 4                  Stray Cats  04/18/2017 12:00:00 AM       Foster    False
#
#                returndate returnedreason deceaseddate deceasedreason  \
# 0                     NaN          Stray          NaN   Died in care
# 1                     NaN          Stray          NaN   Died in care
# 2  02/28/2020 12:00:00 AM          Stray          NaN   Died in care
# 3                     NaN          Stray          NaN   Died in care
# 4  05/29/2018 12:00:00 AM          Stray          NaN   Died in care
#
#    diedoffshelter  puttosleep  isdoa  animalage_years
# 0           False       False  False               11
# 1           False       False  False               10
# 2           False       False  False                8
# 3           False       False  False                8
# 4           False       False  False               10

# %%
shelter.movementtype.value_counts()
# Out:
# Adoption            11051
# Foster               4973
# Reclaimed            2485
# Transfer              710
# None                   55
# Released To Wild       36
# Escaped                 9
# Stolen                  8
# Name: movementtype, dtype: int64

# %%
shelter.animalage_years.value_counts()
# Out:
# 1      3606
# 2      3421
# 3      2856
# 8      2661
# 4      1354
# 5       898
# 7       712
# 6       705
# 11      587
# 10      576
# 9       518
# 12      217
# 14      175
# 13      170
# 16      121
# 15      114
# 21       86
# 22       67
# 17       59
# 18       58
# 23       49
# 24       47
# 19       47
# 25       46
# 26       35
# 20       31
# 30       20
# 31       15
# 101      10
# 28        9
# 35        9
# 34        9
# 32        9
# 99        7
# 33        6
# 100       4
# 29        4
# 102       3
# 37        2
# 58        1
# 36        1
# 972       1
# 0         1
# Name: animalage_years, dtype: int64

# %%
plt.title('Movement Type')
shelter['movementtype'].value_counts().nlargest(5).plot.bar()
# Out:
# <AxesSubplot:title={'center':'Movement Type'}>

# %%
plt.title('Animal Age')
shelter['animalage_years'].value_counts().nlargest(5).plot.bar()
# Out:
# <AxesSubplot:title={'center':'Animal Age'}>

# %%
round(shelter.groupby(['animalage_years']).mean(),2)
# Out:
#                        id  istransfer  istrial  diedoffshelter  puttosleep  \
# animalage_years
# 0                70632.00        0.00      0.0            0.00        0.00
# 1                65303.66        0.00      0.0            0.00        0.01
# 2                62303.57        0.00      0.0            0.00        0.01
# 3                59729.32        0.01      0.0            0.00        0.01
# 4                59987.58        0.01      0.0            0.00        0.02
# 5                61003.30        0.01      0.0            0.00        0.04
# 6                63139.45        0.01      0.0            0.00        0.03
# 7                64014.29        0.01      0.0            0.00        0.01
# 8                67370.22        0.00      0.0            0.00        0.00
# 9                64693.16        0.01      0.0            0.00        0.03
# 10               64350.45        0.00      0.0            0.01        0.04
# 11               64008.40        0.00      0.0            0.01        0.01
# 12               61882.18        0.00      0.0            0.02        0.08
# 13               62392.06        0.01      0.0            0.02        0.05
# 14               62962.78        0.00      0.0            0.03        0.09
# 15               63094.61        0.00      0.0            0.04        0.09
# 16               64855.43        0.00      0.0            0.00        0.07
# 17               68430.53        0.00      0.0            0.00        0.07
# 18               67143.45        0.00      0.0            0.00        0.05
# 19               68913.89        0.00      0.0            0.00        0.06
# 20               70990.23        0.00      0.0            0.03        0.00
# 21               70717.64        0.00      0.0            0.01        0.00
# 22               71368.52        0.00      0.0            0.00        0.00
# 23               71226.92        0.00      0.0            0.00        0.00
# 24               70803.21        0.00      0.0            0.00        0.00
# 25               70928.35        0.00      0.0            0.02        0.00
# 26               70780.06        0.00      0.0            0.00        0.00
# 28               65205.67        0.00      0.0            0.00        0.11
# 29               63074.50        0.00      0.0            0.00        0.00
# 30               62564.30        0.00      0.0            0.00        0.05
# 31               57723.53        0.00      0.0            0.00        0.00
# 32               58480.89        0.00      0.0            0.00        0.00
# 33               61914.50        0.00      0.0            0.00        0.00
# 34               62496.67        0.00      0.0            0.00        0.00
# 35               58235.33        0.00      0.0            0.00        0.00
# 36               56397.00        0.00      0.0            0.00        0.00
# 37               55411.50        0.00      0.0            0.00        0.00
# 58               57703.00        0.00      0.0            0.00        0.00
# 99               69029.00        0.00      0.0            0.00        0.00
# 100              62353.00        0.00      0.0            0.00        0.00
# 101              58845.10        0.00      0.0            0.00        0.00
# 102              55935.00        0.00      0.0            0.00        0.00
# 972              56661.00        0.00      0.0            0.00        0.00
#
#                  isdoa
# animalage_years
# 0                 0.00
# 1                 0.00
# 2                 0.00
# 3                 0.00
# 4                 0.00
# 5                 0.00
# 6                 0.00
# 7                 0.01
# 8                 0.00
# 9                 0.00
# 10                0.01
# 11                0.00
# 12                0.01
# 13                0.00
# 14                0.01
# 15                0.04
# 16                0.00
# 17                0.00
# 18                0.00
# 19                0.00
# 20                0.00
# 21                0.01
# 22                0.00
# 23                0.00
# 24                0.02
# 25                0.00
# 26                0.00
# 28                0.00
# 29                0.00
# 30                0.00
# 31                0.00
# 32                0.00
# 33                0.00
# 34                0.00
# 35                0.00
# 36                0.00
# 37                0.00
# 58                0.00
# 99                0.00
# 100               0.00
# 101               0.00
# 102               0.00
# 972               0.00

# %%
shelter.groupby('movementtype').boxplot(fontsize=20,rot=90,figsize=(20,10),patch_artist=True)
# Out:
# Adoption                 AxesSubplot(0.1,0.679412;0.235294x0.220588)
# Escaped             AxesSubplot(0.382353,0.679412;0.235294x0.220588)
# Foster              AxesSubplot(0.664706,0.679412;0.235294x0.220588)
# None                     AxesSubplot(0.1,0.414706;0.235294x0.220588)
# Reclaimed           AxesSubplot(0.382353,0.414706;0.235294x0.220588)
# Released To Wild    AxesSubplot(0.664706,0.414706;0.235294x0.220588)
# Stolen                       AxesSubplot(0.1,0.15;0.235294x0.220588)
# Transfer                AxesSubplot(0.382353,0.15;0.235294x0.220588)
# dtype: object

# %%
shelter.groupby('movementtype').speciesname.value_counts().unstack(0).plot.barh()
# Out:
# <AxesSubplot:ylabel='speciesname'>

# %%
shelter1 = shelter['movementdate'].str.split(' ', expand = True)

# %%
shelter1.head()
# Out:
#             0         1   2
# 0  05/13/2017  12:00:00  AM
# 1  04/24/2017  12:00:00  AM
# 2  04/15/2017  12:00:00  AM
# 3  02/29/2020  12:00:00  AM
# 4  04/18/2017  12:00:00  AM

# %%
shelter1 = shelter['movementdate'].str.split(' ', expand = True).rename(columns = lambda x: "movementDate"+str(x+1))

# %%
shelter1.head()
# Out:
#   movementDate1 movementDate2 movementDate3
# 0    05/13/2017      12:00:00            AM
# 1    04/24/2017      12:00:00            AM
# 2    04/15/2017      12:00:00            AM
# 3    02/29/2020      12:00:00            AM
# 4    04/18/2017      12:00:00            AM

# %%
shelter2 = pd.concat([shelter, shelter1], axis = 1)

# %%
shelter2.head()
# Out:
#       id              intakedate intakereason  istransfer sheltercode  \
# 0  15801  11/28/2009 12:00:00 AM       Moving       False   C09115463
# 1  15932  12/08/2009 12:00:00 AM       Moving       False   D09125594
# 2  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 3  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 4  30812  01/11/2013 12:00:00 AM    Abandoned       False    C1301091
#
#   identichipnumber   animalname                breedname  \
# 0       0A115D7358       Jadzia      Domestic Short Hair
# 1       0A11675477        Gonzo  German Shepherd Dog/Mix
# 2       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 3       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 4       0A13403D4D  Pretty Girl      Domestic Short Hair
#
#              basecolour speciesname           animalage sexname  \
# 0         Tortoiseshell         Cat  11 years 8 months.  Female
# 1                   Tan         Dog  10 years 9 months.    Male
# 2               Various         Dog    8 years 1 month.  Female
# 3               Various         Dog    8 years 1 month.  Female
# 4  Dilute tortoiseshell         Cat  10 years 6 months.  Female
#
#                      location            movementdate movementtype  istrial  \
# 0  Adoptable Cat Glass Colony  05/13/2017 12:00:00 AM     Adoption    False
# 1              Adoptable Dogs  04/24/2017 12:00:00 AM     Adoption    False
# 2          Canine intake room  04/15/2017 12:00:00 AM     Adoption    False
# 3          Canine intake room  02/29/2020 12:00:00 AM    Reclaimed    False
# 4                  Stray Cats  04/18/2017 12:00:00 AM       Foster    False
#
#                returndate returnedreason deceaseddate deceasedreason  \
# 0                     NaN          Stray          NaN   Died in care
# 1                     NaN          Stray          NaN   Died in care
# 2  02/28/2020 12:00:00 AM          Stray          NaN   Died in care
# 3                     NaN          Stray          NaN   Died in care
# 4  05/29/2018 12:00:00 AM          Stray          NaN   Died in care
#
#    diedoffshelter  puttosleep  isdoa  animalage_years movementDate1  \
# 0           False       False  False               11    05/13/2017
# 1           False       False  False               10    04/24/2017
# 2           False       False  False                8    04/15/2017
# 3           False       False  False                8    02/29/2020
# 4           False       False  False               10    04/18/2017
#
#   movementDate2 movementDate3
# 0      12:00:00            AM
# 1      12:00:00            AM
# 2      12:00:00            AM
# 3      12:00:00            AM
# 4      12:00:00            AM

# %%
shelter2.drop(['movementdate'], axis=1)
# Out:
#           id              intakedate                       intakereason  \
# 0      15801  11/28/2009 12:00:00 AM                             Moving
# 1      15932  12/08/2009 12:00:00 AM                             Moving
# 2      28859  08/10/2012 12:00:00 AM                          Abandoned
# 3      28859  08/10/2012 12:00:00 AM                          Abandoned
# 4      30812  01/11/2013 12:00:00 AM                          Abandoned
# ...      ...                     ...                                ...
# 19322  72232  01/13/2022 12:43:18 PM  Incompatible with owner lifestyle
# 19323  72233  01/13/2022 01:20:50 PM                              Stray
# 19324  72245  01/14/2022 10:24:03 AM                              Stray
# 19325  72252  01/15/2022 10:06:40 AM                              Stray
# 19326  72252  01/15/2022 10:06:40 AM                              Stray
#
#        istransfer sheltercode identichipnumber   animalname  \
# 0           False   C09115463       0A115D7358       Jadzia
# 1           False   D09125594       0A11675477        Gonzo
# 2           False   D12082309       0A13253C7B       Maggie
# 3           False   D12082309       0A13253C7B       Maggie
# 4           False    C1301091       0A13403D4D  Pretty Girl
# ...           ...         ...              ...          ...
# 19322       False    C2201042  981020045230711         Loki
# 19323       False    H2201042              NaN    stray bun
# 19324       False    D2201044  982091063915522        Bruno
# 19325       False    D2201051              NaN        Chloe
# 19326       False    D2201051              NaN        Chloe
#
#                                    breedname            basecolour  \
# 0                        Domestic Short Hair         Tortoiseshell
# 1                    German Shepherd Dog/Mix                   Tan
# 2                    Shep Mix/Siberian Husky               Various
# 3                    Shep Mix/Siberian Husky               Various
# 4                        Domestic Short Hair  Dilute tortoiseshell
# ...                                      ...                   ...
# 19322                     Domestic Long Hair        Grey and White
# 19323                               American       Black and White
# 19324  Australian Cattle Dog/Bully Breed Mix       White and Liver
# 19325                                 Beagle       White and Black
# 19326                                 Beagle       White and Black
#
#         speciesname           animalage  sexname                    location  \
# 0               Cat  11 years 8 months.   Female  Adoptable Cat Glass Colony
# 1               Dog  10 years 9 months.     Male              Adoptable Dogs
# 2               Dog    8 years 1 month.   Female          Canine intake room
# 3               Dog    8 years 1 month.   Female          Canine intake room
# 4               Cat  10 years 6 months.   Female                  Stray Cats
# ...             ...                 ...      ...                         ...
# 19322           Cat   3 years 0 months.     Male       Adoptable Cat Kennels
# 19323  House Rabbit  99 years 0 months.  Unknown          Feline intake room
# 19324           Dog   1 year 11 months.     Male                  Dog room C
# 19325           Dog  16 years 0 months.   Female                  Dog room A
# 19326           Dog  16 years 0 months.   Female                  Dog room A
#
#       movementtype  istrial              returndate returnedreason  \
# 0         Adoption    False                     NaN          Stray
# 1         Adoption    False                     NaN          Stray
# 2         Adoption    False  02/28/2020 12:00:00 AM          Stray
# 3        Reclaimed    False                     NaN          Stray
# 4           Foster    False  05/29/2018 12:00:00 AM          Stray
# ...            ...      ...                     ...            ...
# 19322     Adoption    False                     NaN          Stray
# 19323       Foster    False                     NaN          Stray
# 19324    Reclaimed    False                     NaN          Stray
# 19325    Reclaimed    False  01/16/2022 12:00:00 AM          Stray
# 19326    Reclaimed    False                     NaN          Stray
#
#       deceaseddate      deceasedreason  diedoffshelter  puttosleep  isdoa  \
# 0              NaN        Died in care           False       False  False
# 1              NaN        Died in care           False       False  False
# 2              NaN        Died in care           False       False  False
# 3              NaN        Died in care           False       False  False
# 4              NaN        Died in care           False       False  False
# ...            ...                 ...             ...         ...    ...
# 19322          NaN  Court Order/ Legal           False       False  False
# 19323          NaN  Court Order/ Legal           False       False  False
# 19324          NaN  Court Order/ Legal           False       False  False
# 19325          NaN  Court Order/ Legal           False       False  False
# 19326          NaN  Court Order/ Legal           False       False  False
#
#        animalage_years movementDate1
# 0                   11    05/13/2017
# 1                   10    04/24/2017
# 2                    8    04/15/2017
# 3                    8    02/29/2020
# 4                   10    04/18/2017
# ...                ...           ...
# 19322                3    01/13/2022
# 19323               99    01/13/2022
# 19324                1    01/15/2022
# 19325               16    01/16/2022
# 19326               16    01/16/2022
#
# [19327 rows x 24 columns]

# %%
shelter2.rename(columns={'movementDate1' : 'movementDate'}, inplace=True)

# %%
shelter2.head()
# Out:
#       id              intakedate intakereason  istransfer sheltercode  \
# 0  15801  11/28/2009 12:00:00 AM       Moving       False   C09115463
# 1  15932  12/08/2009 12:00:00 AM       Moving       False   D09125594
# 2  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 3  28859  08/10/2012 12:00:00 AM    Abandoned       False   D12082309
# 4  30812  01/11/2013 12:00:00 AM    Abandoned       False    C1301091
#
#   identichipnumber   animalname                breedname  \
# 0       0A115D7358       Jadzia      Domestic Short Hair
# 1       0A11675477        Gonzo  German Shepherd Dog/Mix
# 2       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 3       0A13253C7B       Maggie  Shep Mix/Siberian Husky
# 4       0A13403D4D  Pretty Girl      Domestic Short Hair
#
#              basecolour speciesname           animalage sexname  \
# 0         Tortoiseshell         Cat  11 years 8 months.  Female
# 1                   Tan         Dog  10 years 9 months.    Male
# 2               Various         Dog    8 years 1 month.  Female
# 3               Various         Dog    8 years 1 month.  Female
# 4  Dilute tortoiseshell         Cat  10 years 6 months.  Female
#
#                      location            movementdate movementtype  istrial  \
# 0  Adoptable Cat Glass Colony  05/13/2017 12:00:00 AM     Adoption    False
# 1              Adoptable Dogs  04/24/2017 12:00:00 AM     Adoption    False
# 2          Canine intake room  04/15/2017 12:00:00 AM     Adoption    False
# 3          Canine intake room  02/29/2020 12:00:00 AM    Reclaimed    False
# 4                  Stray Cats  04/18/2017 12:00:00 AM       Foster    False
#
#                returndate returnedreason deceaseddate deceasedreason  \
# 0                     NaN          Stray          NaN   Died in care
# 1                     NaN          Stray          NaN   Died in care
# 2  02/28/2020 12:00:00 AM          Stray          NaN   Died in care
# 3                     NaN          Stray          NaN   Died in care
# 4  05/29/2018 12:00:00 AM          Stray          NaN   Died in care
#
#    diedoffshelter  puttosleep  isdoa  animalage_years movementDate  \
# 0           False       False  False               11   05/13/2017
# 1           False       False  False               10   04/24/2017
# 2           False       False  False                8   04/15/2017
# 3           False       False  False                8   02/29/2020
# 4           False       False  False               10   04/18/2017
#
#   movementDate2 movementDate3
# 0      12:00:00            AM
# 1      12:00:00            AM
# 2      12:00:00            AM
# 3      12:00:00            AM
# 4      12:00:00            AM

# %%
shelter2.drop(['movementdate', 'movementDate2', 'movementDate3', 'deceaseddate', 'deceasedreason', 'diedoffshelter', 
               'puttosleep', 'isdoa'], axis=1)
# Out:
#           id              intakedate                       intakereason  \
# 0      15801  11/28/2009 12:00:00 AM                             Moving
# 1      15932  12/08/2009 12:00:00 AM                             Moving
# 2      28859  08/10/2012 12:00:00 AM                          Abandoned
# 3      28859  08/10/2012 12:00:00 AM                          Abandoned
# 4      30812  01/11/2013 12:00:00 AM                          Abandoned
# ...      ...                     ...                                ...
# 19322  72232  01/13/2022 12:43:18 PM  Incompatible with owner lifestyle
# 19323  72233  01/13/2022 01:20:50 PM                              Stray
# 19324  72245  01/14/2022 10:24:03 AM                              Stray
# 19325  72252  01/15/2022 10:06:40 AM                              Stray
# 19326  72252  01/15/2022 10:06:40 AM                              Stray
#
#        istransfer sheltercode identichipnumber   animalname  \
# 0           False   C09115463       0A115D7358       Jadzia
# 1           False   D09125594       0A11675477        Gonzo
# 2           False   D12082309       0A13253C7B       Maggie
# 3           False   D12082309       0A13253C7B       Maggie
# 4           False    C1301091       0A13403D4D  Pretty Girl
# ...           ...         ...              ...          ...
# 19322       False    C2201042  981020045230711         Loki
# 19323       False    H2201042              NaN    stray bun
# 19324       False    D2201044  982091063915522        Bruno
# 19325       False    D2201051              NaN        Chloe
# 19326       False    D2201051              NaN        Chloe
#
#                                    breedname            basecolour  \
# 0                        Domestic Short Hair         Tortoiseshell
# 1                    German Shepherd Dog/Mix                   Tan
# 2                    Shep Mix/Siberian Husky               Various
# 3                    Shep Mix/Siberian Husky               Various
# 4                        Domestic Short Hair  Dilute tortoiseshell
# ...                                      ...                   ...
# 19322                     Domestic Long Hair        Grey and White
# 19323                               American       Black and White
# 19324  Australian Cattle Dog/Bully Breed Mix       White and Liver
# 19325                                 Beagle       White and Black
# 19326                                 Beagle       White and Black
#
#         speciesname           animalage  sexname                    location  \
# 0               Cat  11 years 8 months.   Female  Adoptable Cat Glass Colony
# 1               Dog  10 years 9 months.     Male              Adoptable Dogs
# 2               Dog    8 years 1 month.   Female          Canine intake room
# 3               Dog    8 years 1 month.   Female          Canine intake room
# 4               Cat  10 years 6 months.   Female                  Stray Cats
# ...             ...                 ...      ...                         ...
# 19322           Cat   3 years 0 months.     Male       Adoptable Cat Kennels
# 19323  House Rabbit  99 years 0 months.  Unknown          Feline intake room
# 19324           Dog   1 year 11 months.     Male                  Dog room C
# 19325           Dog  16 years 0 months.   Female                  Dog room A
# 19326           Dog  16 years 0 months.   Female                  Dog room A
#
#       movementtype  istrial              returndate returnedreason  \
# 0         Adoption    False                     NaN          Stray
# 1         Adoption    False                     NaN          Stray
# 2         Adoption    False  02/28/2020 12:00:00 AM          Stray
# 3        Reclaimed    False                     NaN          Stray
# 4           Foster    False  05/29/2018 12:00:00 AM          Stray
# ...            ...      ...                     ...            ...
# 19322     Adoption    False                     NaN          Stray
# 19323       Foster    False                     NaN          Stray
# 19324    Reclaimed    False                     NaN          Stray
# 19325    Reclaimed    False  01/16/2022 12:00:00 AM          Stray
# 19326    Reclaimed    False                     NaN          Stray
#
#        animalage_years movementDate
# 0                   11   05/13/2017
# 1                   10   04/24/2017
# 2                    8   04/15/2017
# 3                    8   02/29/2020
# 4                   10   04/18/2017
# ...                ...          ...
# 19322                3   01/13/2022
# 19323               99   01/13/2022
# 19324                1   01/15/2022
# 19325               16   01/16/2022
# 19326               16   01/16/2022
#
# [19327 rows x 19 columns]
